# %%
import sys
print(sys.path)
# Out:
# ['/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/research', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python39.zip', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9/lib-dynload', '', '/home/dlvaayuai/.local/lib/python3.9/site-packages', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9/site-packages', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/src']

# %%
import sys

# Remove the undesired directory from sys.path temporarily
undesired_path = '/home/dlvaayuai/.local/lib/python3.9/site-packages'
if undesired_path in sys.path:
    sys.path.remove(undesired_path)

# %%
import sys
print(sys.path)
# Out:
# ['/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/research', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python39.zip', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9/lib-dynload', '', '/home/dlvaayuai/.local/lib/python3.9/site-packages', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/txt_sum_pro/lib/python3.9/site-packages', '/home/dlvaayuai/storage/NLP_PROJECT_Krish_Naik/Text_summarizer_Project/src']
